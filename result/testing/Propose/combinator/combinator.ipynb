# %%
import utils
import pandas as pd

# %%
metrics = {'euclid': utils.euclid, 'emd_r1': utils.emd, 'emd_r2': lambda x, y: utils.emd(x, y, r=2)}
corrs = {'lcc': utils.lcc, 'srcc': utils.srcc}

# %%
def sub_test(file, start = None, end = None, title = ''):
    data = pd.read_csv(file, header=None)
    # data = preds.merge(pd.read_csv('./merge__test_labels.csv', header=None), on=0)
    sum_data = utils.summarize(data=data, metrics=metrics, corrs=corrs)
    filter = utils.show_detail(sum_data, 'mean', figsize=(20, 10), count=min(len(sum_data), 2000), title=title, start=start, end=end)
    utils.compare_with_ground_truth(filter, ['mean', 'std'])
    return sum_data

# %% [markdown]
# ## Combinator

# %% [markdown]
# ### Version 7

# %%
v7 = sub_test('./t2_combinator_v7-epoch_94.csv', None, None, 'Combinator v7')
# Out:
# Accuracy     : 80.15%
# DIFF_MEAN    : 0.41146 [mean] 3.30985 [max] 0.00008 [min]
# DIFF_STD     : 0.18295 [mean] 0.90939 [max] 0.00005 [min]
# EUCLID       : 0.14610 [mean] 0.72416 [max] 0.02534 [min]
# EMD_R1       : 0.04788 [mean] 0.33098 [max] 0.00564 [min]
# EMD_R2       : 0.06689 [mean] 0.43902 [max] 0.00785 [min]
# LCC    [mean]: (0.7030597760885257, 0.0)
# LCC     [std]: (0.31300571223301726, 2.5135940373603653e-289)
# SRCC   [mean]: (0.696615270495482, 0.0)
# SRCC    [std]: (0.299917394349526, 1.1468408908965398e-264)
# There are 12818 samples in range [None, None]

# %% [markdown]
# ### Version 9

# %%
v9 = sub_test('./t2_combinator_v9-epoch_78.csv', None, None, 'Combinator v9')
# Out:
# Accuracy     : 80.18%
# DIFF_MEAN    : 0.40602 [mean] 3.25540 [max] 0.00000 [min]
# DIFF_STD     : 0.18163 [mean] 0.91299 [max] 0.00000 [min]
# EUCLID       : 0.14424 [mean] 0.72938 [max] 0.01907 [min]
# EMD_R1       : 0.04711 [mean] 0.32554 [max] 0.00453 [min]
# EMD_R2       : 0.06606 [mean] 0.43677 [max] 0.00577 [min]
# LCC    [mean]: (0.7054931394632746, 0.0)
# LCC     [std]: (0.304371643563631, 6.452910726695276e-273)
# SRCC   [mean]: (0.6970278241166181, 0.0)
# SRCC    [std]: (0.29371508454983464, 2.019230234635157e-253)
# There are 12818 samples in range [None, None]
