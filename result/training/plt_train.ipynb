# %%
from utils import plot_trainning

# %% [markdown]
# # Paper Split Dataset

# %% [markdown]
# ## Classifier

# %%
# optimizer: Adam(features: 5e-5, classifier: 5e-4)
# lr decay: onplateu(patience=10, factor=0.95)
# unfreeze after: 2
plot_trainning('./t2_classifier_v3.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0179 at 48
# MIN [  val] = 0.4622 at 7

# %%
# optimizer: Adam(features: 5e-4, classifier: 5e-3)
# lr decay: onplateu(patience=10, factor=0.95)
# unfreeze after: 2
plot_trainning('./t2_classifier_v2.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0268 at 43
# MIN [  val] = 0.4636 at 4

# %%
# optimizer: Adam(features: 5e-5, classifier: 5e-4)
# lr decay: onplateu(patience=10, factor=0.95)
# unfreeze after: 2
plot_trainning('./t2_classifier_v1.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.6582 at 88
# MIN [  val] = 0.7138 at 21

# %% [markdown]
# ## Combinator

# %%
# optimizer: Adam(1e-3)
# lr decay: onplateu(patience=10, factor=0.95)
# layers: 30, 300, 300, 10
# batch size: 128
plot_trainning('./t2_combinator_v9.csv', ['train', 'val'], vertical_line_at = None, cut_from=10)
# Out:
# MIN [train] = 0.0671 at 100
# MIN [  val] = 0.0661 at 78

# %%
# optimizer: Adam(5e-3)
# lr decay: onplateu(patience=5, factor=0.7)
# layers: 30, 300, 300, 10
plot_trainning('./t2_combinator_v8.csv', ['train', 'val'], vertical_line_at = None, cut_from=10)
# Out:
# MIN [train] = 0.0704 at 99
# MIN [  val] = 0.0698 at 98

# %%
# optimizer: Adam(1e-3)
# lr decay: onplateu(patience=5, factor=0.7)
# layers: 30, 300, 300, 10
plot_trainning('./t2_combinator_v7.csv', ['train', 'val'], vertical_line_at = None, cut_from=15)
# Out:
# MIN [train] = 0.0676 at 98
# MIN [  val] = 0.0669 at 94

# %%
# optimizer: Adam(1e-3)
# lr decay: onplateu(patience=5, factor=0.7)
# layers: 30, 200, 200, 10
plot_trainning('./t2_combinator_v6.csv', ['train', 'val'], vertical_line_at = None, cut_from=16)
# Out:
# MIN [train] = 0.0686 at 99
# MIN [  val] = 0.0678 at 98

# %%
# optimizer: Adam(5e-4)
# lr decay: onplateu(patience=5, factor=0.7)
# layers: 30, 100, 100, 10
plot_trainning('./t2_combinator_v5.csv', ['train', 'val'], vertical_line_at = None, cut_from=15)
# Out:
# MIN [train] = 0.0961 at 100
# MIN [  val] = 0.0957 at 99

# %%
# optimizer: Adam(1e-3)
# lr decay: onplateu(patience=5, factor=0.7)
# layers: 30, 100, 100, 10
plot_trainning('./t2_combinator_v4.csv', ['train', 'val'], vertical_line_at = None, cut_from=14)
# Out:
# MIN [train] = 0.0727 at 100
# MIN [  val] = 0.0719 at 98

# %%
# optimizer: Adam(1e-2)
# lr decay: onplateu(patience=5, factor=0.7)
# layers: 30, 100, 100, 10
plot_trainning('./t2_combinator_v3.csv', ['train', 'val'], vertical_line_at = None, cut_from=5)
# Out:
# MIN [train] = 0.0872 at 99
# MIN [  val] = 0.0866 at 88

# %%
# optimizer: Adam(5e-1)
# lr decay: onplateu(patience=5, factor=0.7)
# layers: 30, 100, 100, 10
plot_trainning('./t2_combinator_v2.csv', ['train', 'val'], vertical_line_at = None, cut_from=5)
# Out:
# MIN [train] = 0.1007 at 94
# MIN [  val] = 0.1006 at 97

# %%
# optimizer: Adam(3e-2)
# lr decay: onplateu(patience=5, factor=0.7)
# layers: 30, 100, 100, 10
plot_trainning('./t2_combinator_v1.csv', ['train', 'val'], vertical_line_at = None, cut_from=5)
# Out:
# MIN [train] = 0.0931 at 99
# MIN [  val] = 0.0925 at 82

# %% [markdown]
# ## Separate Models

# %%
# optimizer: Adam(features: 5e-5, classifier: 5e-4)
# lr decay: onplateu(patience=5, factor=0.9)
# unfreeze: epoch 2
plot_trainning('./t2_group_2_v2.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0260 at 50
# MIN [  val] = 0.0395 at 12

# %%
# optimizer: Adam(features: 5e-5, classifier: 5e-4)
# lr decay: onplateu(patience=5, factor=0.9)
# unfreeze: epoch 2
plot_trainning('./t2_group_0_v2.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0297 at 50
# MIN [  val] = 0.0458 at 10

# %%
# optimizer: Adam(features: 5e-5, classifier: 5e-4)
# lr decay: onplateu(patience=2, factor=0.5)
# unfreeze: epoch 2
plot_trainning('./t2_group_0_v1.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0354 at 43
# MIN [  val] = 0.0453 at 9

# %% [markdown]
# ====> CHOOSE:
# - optimizer: Adam(features: 5e-5, classifier: 5e-4)
# - lr decay: onplateu(patience=3, factor=0.7)
# - unfreeze: epoch 2

# %%
# optimizer: Adam(features: 1e-5, classifier: 1e-4)
# lr decay: onplateu(patience=3, factor=0.9)
# unfreeze: epoch 2
plot_trainning('./t2_group_1_v6.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0441 at 50
# MIN [  val] = 0.0534 at 21

# %%
# optimizer: Adam(features: 5e-6, classifier: 5e-5)
# lr decay: onplateu(patience=3, factor=0.9)
# unfreeze: epoch 2
plot_trainning('./t2_group_1_v5.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0487 at 50
# MIN [  val] = 0.0535 at 46

# %%
# optimizer: Adam(features: 1e-2, classifier: 1e-1)
# lr decay: onplateu(patience=3, factor=0.5)
# unfreeze: epoch 2
plot_trainning('./t2_group_1_v4.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.1904 at 4
# MIN [  val] = 0.1906 at 3

# %%
# optimizer: Adam(features: 5e-5, classifier: 5e-4)
# lr decay: onplateu(patience=3, factor=0.7)
# unfreeze: epoch 2
plot_trainning('./t2_group_1_v3.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0372 at 36
# MIN [  val] = 0.0534 at 7

# %%
# optimizer: SGD(features: 5e-4, classifier: 5e-3, momentum: 0.9)
# lr decay: exponential(freq=5, gamma=0.95)
# unfreeze: epoch 2
plot_trainning('./t2_group_1_v2.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0626 at 25
# MIN [  val] = 0.0610 at 24

# %%
# optimizer: Adam(features: 5e-4, classifier: 5e-3)
# lr decay: onplateau(patience=5, factor=0.95)
# unfreeze: epoch 2
plot_trainning('./t2_group_1_v1.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0326 at 34
# MIN [  val] = 0.0552 at 7

# %% [markdown]
# # Custom Split Dataset

# %%
# optimizer: Adam(features: 5e-4, classifier: 5e-3)
# lr decay: onplateau(patience=5, factor=0.75)
# unfreeze: epoch 5
plot_trainning('./t1_group_1_v1.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0353 at 24
# MIN [  val] = 0.0564 at 12

# %%
# optimizer: Adam(features: 1e-3, classifier: 1e-2)
# lr decay: onplateau(patience=5, factor=0.75)
# unfreeze: epoch 5
plot_trainning('./t1_group_0_v6.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0146 at 50
# MIN [  val] = 0.0455 at 10

# %%
# optimizer: Adam(features: 5e-4, classifiers: 5e-3)
# lr decay: onplateau(patience=5, factor=0.5)
# unfreeze: epoch 5
plot_trainning('./t1_group_0_v5.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0177 at 50
# MIN [  val] = 0.0450 at 8

# %%
# optimizer: Adam(features: 5e-4, classifiers: 5e-3)
# lr decay: exponential(freq=10, gamma=0.4)
# unfreeze: epoch 5
plot_trainning('./t1_group_0_v4.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0184 at 50
# MIN [  val] = 0.0455 at 9

# %%
# optimizer: Adam(features: 5e-4, classifiers: 5e-3)
# lr decay: exponential(freq=10, gamma=0.7)
# unfreeze: epoch 5
plot_trainning('./t1_group_0_v3.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0189 at 33
# MIN [  val] = 0.0453 at 8

# %%
# optimizer: Adam(features: 5e-4, classifiers: 5e-3)
# lr decay: exponential(freq=10, gamma=0.95)
# unfreeze: epoch 5
plot_trainning('./t1_group_0_v2.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0169 at 50
# MIN [  val] = 0.0451 at 9

# %%
# optimizer: Adam(features: 5e-4, classifiers: 5e-3)
# lr decay: exponential(freq=5, gamma=0.7)
# unfreeze: epoch 5
plot_trainning('./t1_group_0_v1.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0177 at 50
# MIN [  val] = 0.0448 at 8

# %%
# optimizer: Adam(features=5e-4, classifiers=5e-3)
plot_trainning('./rerun_1.csv', ['train', 'val'])
# Out:
# MIN [train] = 0.0530 at 14
# MIN [  val] = 0.0660 at 4

# %%
# optimizer: Adam(features=9.5e-5, classifiers=9.5e-4)
plot_trainning('./rerun_2.csv', ['train', 'val'])
# Out:
# MIN [train] = 0.0460 at 18
# MIN [  val] = 0.0646 at 9

# %% [markdown]
# # Retrain Paper

# %%
# optimizer: Adam(features: 5e-5, classifier: 5e-4)
# lr decay: onplateu(patience=3, factor=0.7)
# unfreeze: epoch 2
plot_trainning('./t2_paper.csv', ['train', 'val'], vertical_line_at = None)
# Out:
# MIN [train] = 0.0432 at 41
# MIN [  val] = 0.0630 at 7
